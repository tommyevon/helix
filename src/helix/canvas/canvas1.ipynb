# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helix.core.data import data_getters

# %%
data_getters.get_new_issue()
# Out:
#            deal class  size      ipt guidance pricing   status  \
# 0  HALST 2023-1    A1   280   S+162a    S+147   S+136  Settled
# 1  HALST 2023-1    A2   140   S+168a    S+145   S+135  Settled
# 2  HALST 2023-1     B    70   S+216a    S+203   S+198  Settled
# 3  HALST 2023-1     C    56   S+281a    S+275   S+263  Settled
# 4  HALST 2023-1     D    49   S+377a    S+367   S+359  Settled
# 5  HALST 2023-1     E    35   S+540a    S+532   S+526  Settled
# 6  HALST 2023-1     F    28   S+743a    S+727   S+718  Settled
# 7  HALST 2023-1     G    42  S+1018a   S+1006  S+1001  Settled
# 8  RALI 2024-10    A1   115   S+164a    S+148   S+131   Priced
# 9  RALI 2024-10    A2    58   S+152a    S+148   S+134   Priced
#
#                                          notes
# 0            Strong demand from money managers
# 1            Strong demand from money managers
# 2                  3x oversubscribed at launch
# 3                 B-piece sold to single buyer
# ...
